# %%
pip install haystack-ai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting haystack-ai
#   Downloading haystack_ai-2.22.0-py3-none-any.whl.metadata (15 kB)
# Collecting docstring-parser (from haystack-ai)
#   Downloading docstring_parser-0.17.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting filetype (from haystack-ai)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting haystack-experimental (from haystack-ai)
#   Downloading haystack_experimental-0.16.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from haystack-ai) (3.1.2)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from haystack-ai) (4.17.0)
# Collecting lazy-imports (from haystack-ai)
#   Downloading lazy_imports-1.2.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: more-itertools in /usr/lib/python3/dist-packages (from haystack-ai) (8.10.0)
# Requirement already satisfied: networkx in /home/chengxi/.local/lib/python3.10/site-packages (from haystack-ai) (3.4.2)
# Requirement already satisfied: numpy in /home/chengxi/.local/lib/python3.10/site-packages (from haystack-ai) (2.2.6)
# Requirement already satisfied: openai>=1.99.2 in /home/chengxi/.local/lib/python3.10/site-packages (from haystack-ai) (2.15.0)
# Collecting posthog!=3.12.0 (from haystack-ai)
#   Downloading posthog-7.6.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pydantic in /home/chengxi/.local/lib/python3.10/site-packages (from haystack-ai) (2.12.5)
# Requirement already satisfied: python-dateutil in /home/chengxi/.local/lib/python3.10/site-packages (from haystack-ai) (2.9.0.post0)
# Requirement already satisfied: pyyaml in /home/chengxi/.local/lib/python3.10/site-packages (from haystack-ai) (6.0.3)
# Requirement already satisfied: requests in /home/chengxi/.local/lib/python3.10/site-packages (from haystack-ai) (2.32.5)
# Requirement already satisfied: tenacity!=8.4.0 in /home/chengxi/.local/lib/python3.10/site-packages (from haystack-ai) (9.1.2)
# Requirement already satisfied: tqdm in /home/chengxi/.local/lib/python3.10/site-packages (from haystack-ai) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.7 in /home/chengxi/.local/lib/python3.10/site-packages (from haystack-ai) (4.15.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/chengxi/.local/lib/python3.10/site-packages (from openai>=1.99.2->haystack-ai) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.99.2->haystack-ai) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/chengxi/.local/lib/python3.10/site-packages (from openai>=1.99.2->haystack-ai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /home/chengxi/.local/lib/python3.10/site-packages (from openai>=1.99.2->haystack-ai) (0.12.0)
# Requirement already satisfied: sniffio in /home/chengxi/.local/lib/python3.10/site-packages (from openai>=1.99.2->haystack-ai) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/chengxi/.local/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai>=1.99.2->haystack-ai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /home/chengxi/.local/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai>=1.99.2->haystack-ai) (3.11)
# Requirement already satisfied: certifi in /home/chengxi/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai>=1.99.2->haystack-ai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /home/chengxi/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai>=1.99.2->haystack-ai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/chengxi/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.99.2->haystack-ai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/chengxi/.local/lib/python3.10/site-packages (from pydantic->haystack-ai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/chengxi/.local/lib/python3.10/site-packages (from pydantic->haystack-ai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/chengxi/.local/lib/python3.10/site-packages (from pydantic->haystack-ai) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from posthog!=3.12.0->haystack-ai) (1.16.0)
# Collecting backoff>=1.10.0 (from posthog!=3.12.0->haystack-ai)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/chengxi/.local/lib/python3.10/site-packages (from requests->haystack-ai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/chengxi/.local/lib/python3.10/site-packages (from requests->haystack-ai) (2.6.3)
# Collecting rich (from haystack-experimental->haystack-ai)
#   Downloading rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->haystack-ai) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/lib/python3/dist-packages (from jsonschema->haystack-ai) (21.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->haystack-ai) (0.19.2)
# Collecting markdown-it-py>=2.2.0 (from rich->haystack-experimental->haystack-ai)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting pygments<3.0.0,>=2.13.0 (from rich->haystack-experimental->haystack-ai)
#   Downloading pygments-2.19.2-py3-none-any.whl.metadata (2.5 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->haystack-experimental->haystack-ai)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading haystack_ai-2.22.0-py3-none-any.whl (643 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 643.7/643.7 kB 2.4 MB/s  0:00:00 eta 0:00:01
# Downloading posthog-7.6.0-py3-none-any.whl (168 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading docstring_parser-0.17.0-py3-none-any.whl (36 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading haystack_experimental-0.16.0-py3-none-any.whl (67 kB)
# Downloading lazy_imports-1.2.0-py3-none-any.whl (18 kB)
# Downloading rich-14.2.0-py3-none-any.whl (243 kB)
# Downloading pygments-2.19.2-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 782.3 kB/s  0:00:01 eta 0:00:01
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# WARNING: Error parsing dependencies of distro-info: Invalid version: '1.1build1'
# WARNING: Error parsing dependencies of python-debian: Invalid version: '0.1.43ubuntu1'
# Installing collected packages: filetype, pygments, mdurl, lazy-imports, docstring-parser, backoff, posthog, markdown-it-py, rich, haystack-experimental, haystack-ai
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/11 [haystack-ai] [haystack-ai]py]
# Successfully installed backoff-2.2.1 docstring-parser-0.17.0 filetype-1.2.0 haystack-ai-2.22.0 haystack-experimental-0.16.0 lazy-imports-1.2.0 markdown-it-py-4.0.0 mdurl-0.1.2 posthog-7.6.0 pygments-2.19.2 rich-14.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from haystack.components.agents import Agent
from haystack.components.generators.chat import OpenAIChatGenerator
from haystack.dataclasses import ChatMessage

# ✅ 建议用 export，而不是写在代码里
os.environ["OPENAI_API_KEY"] = "sk-IWcHVBG9f1UFOHYM3vyXBUJWgQfcbwH7KahozVAYFlLfXkO4"
os.environ["OPENAI_BASE_URL"] = "http://43.159.131.233:3001/v1"

llm = OpenAIChatGenerator(
    model="gpt-5",   # ⚠️ 换成你后端一定支持的
    timeout=60,
)

agent = Agent(
    chat_generator=llm,
    system_prompt="You are a helpful assistant.",
    tools=[],   # ✅ 不使用 web search
)

result = agent.run(
    messages=[ChatMessage.from_user("What is Haystack?")]
)

print(result["last_message"].text)
# Out:
# No tools provided to the Agent. The Agent will behave like a ChatGenerator and only return text responses. To enable tool usage, pass tools directly to the Agent, not to the chat_generator.
# “Haystack” can refer to a few different things. The most common are:
#
# - deepset Haystack: An open-source Python framework for building search and RAG (Retrieval-Augmented Generation) apps—semantic search, question answering, summarization—over your own data. It provides pipelines with components like document stores (e.g., Elasticsearch, FAISS, Weaviate), retrievers (BM25, dense), readers/generators (extractive and LLM-based), rankers, and prompt/agent nodes, and integrates with providers like OpenAI and local Hugging Face models.
#
# - Project Haystack: An open standard for semantic tagging and data modeling in building automation/IoT to make sensor and equipment data interoperable.
#
# - Haystack News: A free, ad-supported streaming news app that aggregates local and global video news.
#
# - MIT Haystack Observatory: A research center focused on radio astronomy, geodesy, and atmospheric science.
#
# Which “Haystack” did you have in mind? If it’s the deepset framework, I can outline how it works, typical architectures, and how to get started.
